# %%
import pandas as pd
import numpy as np

dataset_df = pd.read_csv('../data/padchest_synthetic_data.csv')
dataset_df.head(10)
# Out:
#                                              ImageID  PatientID DateOfBirth  \
# 0  14/633085895779219509971459009045729161_90-397...  PAT000000  2001-07-06
# 1  33/187439760014238126748164906384978689_76-364...  PAT000000  2001-07-06
# 2  28/712544168937306792204156627248465186_17-890...  PAT000000  2001-07-06
# 3  24/648410009713114200720058435592046389_43-579...  PAT000000  2001-07-06
# 4  25/629452468500328973056550860943431369_35-904...  PAT000000  2001-07-06
# 5  27/988817183344796805019006823304453014_89-656...  PAT000000  2001-07-06
# 6  12/281722263942485920658563984759523596_44-850...  PAT000000  2001-07-06
# 7  32/229850736007473401279123692300433589_62-910...  PAT000000  2001-07-06
# 8  13/224213365553634986912878465482855354_61-793...  PAT000000  2001-07-06
# 9  12/893406646567485137760997798902089882_63-889...  PAT000000  2001-07-06
#
#      StudyID PatientSex  PatientHeight  PatientWeight            StudyDate  \
# ...

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21000 entries, 0 to 20999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ImageID          21000 non-null  object
#  1   PatientID        21000 non-null  object
#  2   DateOfBirth      21000 non-null  object
#  3   StudyID          21000 non-null  object
#  4   PatientSex       21000 non-null  object
#  5   PatientHeight    21000 non-null  int64
#  6   PatientWeight    21000 non-null  int64
#  7   StudyDate        21000 non-null  object
#  8   Projection       21000 non-null  object
#  9   Modality         21000 non-null  object
#  10  Location         21000 non-null  object
#  11  InstitutionName  21000 non-null  object
#  12  Labels           21000 non-null  object
#  13  Report           21000 non-null  object
#  14  Findings         21000 non-null  object
#  15  Impression       21000 non-null  object
# ...

# %%
dataset_df['Modality'].unique()
# Out:
# array(['CR', 'RF', 'DX', 'DR'], dtype=object)
